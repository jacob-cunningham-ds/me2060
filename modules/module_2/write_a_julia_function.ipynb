# %% [markdown]
# ---
# title: Write a Julia Function
# venue: Modules
# downloads:
#   - file: write_a_julia_function.ipynb
#     title: write_a_julia_function.ipynb
#   - file: ../../me2060.jl
#     title: me2060.jl
# ---

# %% [markdown]
# The following task is exercise 3 from [the texbook](https://tobydriscoll.net/fnc-julia/intro/algorithms.html).

# %% [markdown]
# **Task Description**
#
# Let $\mathbf{x}=(x_1,x_2,\dots,x_n),\; \mathbf{y}=(y_1,y_2,\dots,y_n) $  be arrays of $n$ Cartesian coordinates for points on a 2D plane, i.e. $P_k=(x_k,y_k)$ is a point with given $x$ and $y$ coordinates $x_k,y_k$.  Assume that these $n$ points vertices of a polygon, given in **counterclockwise** order.
#
# Write a function `polygonarea(x,y)` which takes as arguments the $\mathbf{x},\mathbf{y}$ arrays of coordinates and calculates the area $A$ of the enclosed polygon via [Equation (%s)](#equ-poly-area):
#
# $$
# \label{equ-poly-area}
# \begin{equation}
#   A = \frac{1}{2}\left| \sum_{k=1}^n x_k y_{k+1}-x_{k+1}y_k\right|
# \end{equation}
# $$
#
# :::{hint}
# To form a closed region, $x_{n+1}=x_1$ and $y_{n+1}=y_1$ must be satisfied.
# :::

# %% [markdown]
# The following function is stored in the `me2060` module.
#
# :::{literalinclude} ../../me2060.jl
# :lines: 58-84
# :filename: me2060.jl
# :lang: julia
# :::

# %%
include("me2060.jl")
using Printf
import .me2060

# %%
?me2060.polygon_area

# %% [markdown]
# `````{card} Docstring
# :header: `polygon_area`
#
# Calculate the area of a polygon by using the Shoelace Formula .
#
# The formula is given by:
#
# ```{math}
# \begin{equation*}
#   A = \frac{1}{2} \left | \sum_{k=1}^{n}{x_k y_{k + 1} - x_{k + 1} y_k} \right |
# \end{equation*}
# ```
#
# ````{tab-set}
# ```{tab-item} Parameters
# - `x`: A 1D array of Catersian x-coordinates consisting of real numbers
# - `y`: A 1D array of Cartesian y-coordinates consisting of real numbers
# ```
# ```{tab-item} Returns
# - `area`: A real number representing the area of the polygon.
# ```
# ```{tab-item} Raises
# - TypeError:
#     - If `x` is not a vector consisting of real numbers
#     - If `y` is not a vector consisting of real numbers
# - ArgumentError:
#     - If `x` and `y` are not one dimensional arrays
#     - If `x` and `y` are not the same length
# ```
# ```{tab-item} Limitations
# - Does not account for intersecting geometries.
# ```
# ````
#
# ```{code} julia
# :filename: example
# using Printf
# import .me2060
#
# # coordinates representing a 1x1 square
# x = [0, 0, 1, 1]
# y = [0, 1, 1, 0]
#
# area = me2060.polygon_area(x, y)
# @printf("The area is %.2f: ", area)
# ```
# `````

# %% [markdown]
# Now test your function on a square: $(\mathbf{x},\mathbf{y})= (0,0)-(0,1)-(1,1)-(1,0)$. To visualize it, use the `plot` function. Make sure to add the first element toward the end to close the curve. You can use the `vcat` function to merge two arrays.

# %% [markdown]
# The following function is stored in the `me2060` module.
#
# :::{literalinclude} ../../me2060.jl
# :lines: 126-144
# :filename: me2060.jl
# :lang: julia
# :::

# %%
?me2060.plot_polygon

# %% [markdown]
# `````{card} Docstring
# :header: `plot_polygon`
#
# Plot a polygon based on passed Cartesian coordinates.
#
# ````{tab-set}
# ```{tab-item} Parameters
# - `x`: A 1D array of Catersian x-coordinates consisting of real numbers
# - `y`: A 1D array of Cartesian y-coordinates consisting of real numbers
# ```
# ```{tab-item} Returns
# - Plot of the polygon in $\mathbb{R}^{2}$
# ```
# ```{tab-item} Raises
# - TypeError:
#     - If `x` is not a vector consisting of real numbers
#     - If `y` is not a vector consisting of real numbers
# - ArgumentError:
#     - If `x` and `y` are not one dimensional arrays
#     - If `x` and `y` are not the same length
# ```
# ```{tab-item} Limitations
# - Limited to $\mathbb{R}^{2}$
# ```
# ````
#
# ```{code} julia
# :filename: example
# import .me2060
#
# # coordinates representing a 1x1 square
# x = [0, 0, 1, 1]
# y = [0, 1, 1, 0]
#
# plot_polygon(x, y)
# ```
# `````

# %%
# rectangle coordinates
x_rect = [0, 0, 1, 1]
y_rect = [0, 1, 1, 0]

me2060.plot_polygon(x_rect, y_rect)

# %% [markdown]
# Calculate and print out the area:

# %%
area_rect = me2060.polygon_area(x_rect, y_rect)

@printf("The area of the polygon is: %.2f", area_rect)
# Out:
# The area of the polygon is: 1.00

# %% [markdown]
# Test it now on a triangle: $(\mathbf{x},\mathbf{y})= (0,0)-(0,1)-(1,1)$. First visualize it:

# %%
# triangle coordinates
x_tri = [0, 0, 1]
y_tri = [0, 1, 1]

me2060.plot_polygon(x_tri, y_tri)

# %% [markdown]
# Now calculate the area using your function:

# %%
area_triangle = me2060.polygon_area(x_tri, y_tri)

@printf("The area of the polygon is: %.2f", area_triangle)
# Out:
# The area of the polygon is: 0.50

# %% [markdown]
# **Further explorations**
#
# What happens if you reverse the order of points? Also test it on more complicated polygons such as trapezoids.

# %%
# trapizoid points
x_trap = [0, 4, 3, 1];
y_trap = [0, 0, 2, 2];

# plot the trapezoid
me2060.plot_polygon(x_trap, y_trap)

# %%
# calculate the area
area_trap = me2060.polygon_area(x_trap, y_trap)

@printf("The area of the polygon is: %.2f", area_trap)
# Out:
# The area of the polygon is: 6.00

# %%
# complex polygon
x_complex = [10, 6, 0, -6, -10, -7, 0, 9]
y_complex = [0, 6, 12, 6, 0, -7, -8, -9]

# plot the polygon
me2060.plot_polygon(x_complex, y_complex)

# %%
# calculate the area
area_complex = me2060.polygon_area(x_complex, y_complex)

@printf("The area of the polygon is: %.2f", area_complex)
# Out:
# The area of the polygon is: 276.00

# %% [markdown]
# TODO explore counterclockwise versus clockwise...
